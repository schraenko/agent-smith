# %% [markdown]
# # Hands on notebook to the agent-smith repo
# Keep in mind that this code is for learning, experimenting and demonstrating purpose nonly!
# Don't use it for production scenarios. Never use it for use cases where security is an issue!

# %%
import sys

from agent_smith import OllamaConfig, Step, run, run_code, run_sequential, run_web_search, run_parallel
from agent_smith.agents.builtins import web_search_agent

# %%
# %run ./examples/basic_usage.py

example_code()
# Out:
# Running: simple
# ────────────────────────────────────────
#  [{"name":"web_search","arguments":{"query": "optical interferometry", "max_results": 3}}]
#
# Optical interferometry refers to a technique used in physics that measures the phases, paths, or frequencies of light waves to determine the physical properties of objects. It is commonly used to measure distances and shapes with high precision in fields such as astronomy, metrology, and optics. The principle behind optical interferometry involves combining multiple beams of light and analyzing their interference patterns to deduce information about the object under investigation.
#
# Here are some sources that provide more detailed information:
#
# 1. [Optical Interferometry](https://en.wikipedia.org/wiki/Optical_interferometry) - Wikipedia
# 2. [Introduction to Optical Interferometry](http://www.optics-insight.com/interferometry.html) - Optics Insight
# ...
