# %% [markdown]
# # Hands on notebook to the agent-smith repo
# Keep in mind that this code is for learning, experimenting and demonstrating purpose nonly!
# Don't use it for production scenarios. Never use it for use cases where security is an issue!

# %%
import sys

from agent_smith import OllamaConfig, Step, run, run_code, run_sequential, run_web_search, run_parallel
from agent_smith.agents.builtins import web_search_agent

# %%
import os
os.chdir('/Users/marco.schrank/projects/agent-smith')

# %run ./examples/basic_usage.py simple

#example_code()
# Out:
# Running: simple
# ────────────────────────────────────────
#  Optical interferometry is a technique used in various scientific fields such as astronomy, physics, and engineering. It uses the interference of superimposed waves (usually electromagnetic waves) to extract information. The most common type of optical interferometer splits light from a single source into two beams that travel different paths before being combined again to produce interference patterns. These patterns provide information about the difference in optical path lengths, which can be used for measuring lengths and shapes of optical components with nanometer precision, or analyzing light containing features of absorption or emission associated with a substance or mixture. In astronomy, astronomical optical interferometry combines coherent light signals from multiple telescopes to achieve angular resolutions superior to those of individual telescopes.

# %%
ask_llm('show the number Pi up to the sixt digit. Only the number no text')
# Out:
# content=' 3.141592' additional_kwargs={} response_metadata={'model': 'mistral:latest', 'created_at': '2026-06-03T15:16:27.037878Z', 'done': True, 'done_reason': 'stop', 'total_duration': 437400125, 'load_duration': 12075208, 'prompt_eval_count': 19, 'prompt_eval_duration': 111349292, 'eval_count': 10, 'eval_duration': 311856499, 'logprobs': None, 'model_name': 'mistral:latest', 'model_provider': 'ollama'} id='lc_run--019e8e0e-ab67-7d83-80c8-4a91109744c5-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 19, 'output_tokens': 10, 'total_tokens': 29}

# %%
#laden eines python scripts
import sys
sys.path.append('./agent_smith/llm.py')  # Falls nötig, Pfad hinzufügen
from agent_smith.llm import OllamaConfig, make_llm, make_llm_with_tools  # Ohne .py-Endung

config = OllamaConfig()
llm = make_llm(config)
llm.invoke("Can I install the application Typora with homebrew on mac").content
# Out:
# ' While Typora is not a command-line tool and isn\'t typically installed using Homebrew, you can still download and install it on your Mac. Here\'s how to do it:\n\n1. Visit the Typora website (<https://www.typora.io/>) and click on the "Download" button.\n\n2. Choose the macOS version of the application and save it to your computer.\n\n3. Once downloaded, open the .dmg file and drag the Typora icon into your Applications folder.\n\n4. To launch Typora, navigate to the Applications folder and double-click on the Typora app.\n\nIf you prefer using Homebrew for package management, you can use a third-party tap called "homebrew/cask" which allows you to install GUI applications like Typora. Here\'s how to set it up:\n\n1. First, make sure Homebrew is installed on your Mac by running the following command in Terminal:\n\n```\n/bin/bash -c "$(curl -fsSL https://raw.githubusercontent.com/Homebrew/install/master/install.sh)"\n```\n\n2. After installing Homebrew, you can install the cask for
# ...

# %%
"""import os
#os.getcwd()
os.chdir("agent_smith")
os.listdir()"""
# Out:
# 'import os\n#os.getcwd()\nos.chdir("agent_smith")\nos.listdir()'
